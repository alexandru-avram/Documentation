# %%
import os
import sys

# %%
project_path = os.path.abspath(os.path.join(os.getcwd(), 'first_project'))
sys.path.append(project_path)

# %%
project_path
# Out:
# 'C:\\Users\\alexa\\OneDrive\\Projects\\Documentation\\Python\\03. Web Development\\Django\\first_project\\scripts\\first_project'
